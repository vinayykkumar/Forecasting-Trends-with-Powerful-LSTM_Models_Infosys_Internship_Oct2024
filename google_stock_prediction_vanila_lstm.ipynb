# %% [markdown]
# **STEP 1 - Data Loading and Inspection**

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/stock_dataset.csv') # data_importing
df.head(20) # fetching first 20 rows of dataset
# Out:
#    symbol                       date   close      high       low    open  \
# 0    GOOG  2016-06-14 00:00:00+00:00  718.27  722.4700  713.1200  716.48
# 1    GOOG  2016-06-15 00:00:00+00:00  718.92  722.9800  717.3100  719.00
# 2    GOOG  2016-06-16 00:00:00+00:00  710.36  716.6500  703.2600  714.91
# 3    GOOG  2016-06-17 00:00:00+00:00  691.72  708.8200  688.4515  708.65
# 4    GOOG  2016-06-20 00:00:00+00:00  693.71  702.4800  693.4100  698.77
# 5    GOOG  2016-06-21 00:00:00+00:00  695.94  702.7700  692.0100  698.40
# 6    GOOG  2016-06-22 00:00:00+00:00  697.46  700.8600  693.0819  699.06
# 7    GOOG  2016-06-23 00:00:00+00:00  701.87  701.9500  687.0000  697.45
# 8    GOOG  2016-06-24 00:00:00+00:00  675.22  689.4000  673.4500  675.17
# 9    GOOG  2016-06-27 00:00:00+00:00  668.26  672.3000  663.2840  671.00
# 10   GOOG  2016-06-28 00:00:00+00:00  680.04  680.3300  673.0000  678.97
# 11   GOOG  2016-06-29 00:00:00+00:00  684.11  687.4292  681.4100  683.00
# 12   GOOG  2016-06-30 00:00:00+00:00  692.10  692.3200  683.6500  685.47
# 13   GOOG  2016-07-01 00:00:00+00:00  699.21  700.6500  692.1301  692.20
# 14   GOOG  2016-07-05 00:00:00+00:00  694.49  696.9400  688.8800  696.06
# 15   GOOG  2016-07-06 00:00:00+00:00  697.77  701.6800  689.0900  689.98
# 16   GOOG  2016-07-07 00:00:00+00:00  695.36  698.2000  688.2150  698.08
# 17   GOOG  2016-07-08 00:00:00+00:00  705.63  705.7100  696.4350  699.50
# 18   GOOG  2016-07-11 00:00:00+00:00  715.09  716.5100  707.2400  708.05
# 19   GOOG  2016-07-12 00:00:00+00:00  720.64  722.9400  715.9100  719.12
#
#      volume  adjClose   adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0   1306065    718.27  722.4700  713.1200   716.48    1306065      0.0
# 1   1214517    718.92  722.9800  717.3100   719.00    1214517      0.0
# 2   1982471    710.36  716.6500  703.2600   714.91    1982471      0.0
# 3   3402357    691.72  708.8200  688.4515   708.65    3402357      0.0
# 4   2082538    693.71  702.4800  693.4100   698.77    2082538      0.0
# 5   1465634    695.94  702.7700  692.0100   698.40    1465634      0.0
# 6   1184318    697.46  700.8600  693.0819   699.06    1184318      0.0
# 7   2171415    701.87  701.9500  687.0000   697.45    2171415      0.0
# 8   4449022    675.22  689.4000  673.4500   675.17    4449022      0.0
# 9   2641085    668.26  672.3000  663.2840   671.00    2641085      0.0
# 10  2173762    680.04  680.3300  673.0000   678.97    2173762      0.0
# 11  1932561    684.11  687.4292  681.4100   683.00    1932561      0.0
# 12  1597714    692.10  692.3200  683.6500   685.47    1597714      0.0
# 13  1344710    699.21  700.6500  692.1301   692.20    1344710      0.0
# 14  1462616    694.49  696.9400  688.8800   696.06    1462616      0.0
# 15  1411925    697.77  701.6800  689.0900   689.98    1411925      0.0
# 16  1304200    695.36  698.2000  688.2150   698.08    1304200      0.0
# 17  1575166    705.63  705.7100  696.4350   699.50    1575166      0.0
# 18  1111762    715.09  716.5100  707.2400   708.05    1111762      0.0
# 19  1336921    720.64  722.9400  715.9100   719.12    1336921      0.0
#
#     splitFactor
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# 5           1.0
# 6           1.0
# 7           1.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          1.0
# 14          1.0
# 15          1.0
# 16          1.0
# 17          1.0
# 18          1.0
# 19          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# **STEP 2 - Data Preprocessing**

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(20)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26
# 2016-06-28  678.97  680.04
# 2016-06-29  683.00  684.11
# 2016-06-30  685.47  692.10
# 2016-07-01  692.20  699.21
# 2016-07-05  696.06  694.49
# 2016-07-06  689.98  697.77
# 2016-07-07  698.08  695.36
# 2016-07-08  699.50  705.63
# 2016-07-11  708.05  715.09
# 2016-07-12  719.12  720.64

# %% [markdown]
# **STEP 3 - Data Visualization**

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(20)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000
# 2016-06-28  0.004299  0.006356
# 2016-06-29  0.006473  0.008552
# 2016-06-30  0.007805  0.012863
# 2016-07-01  0.011435  0.016700
# 2016-07-05  0.013517  0.014153
# 2016-07-06  0.010238  0.015923
# 2016-07-07  0.014607  0.014622
# 2016-07-08  0.015373  0.020164
# 2016-07-11  0.019985  0.025268
# 2016-07-12  0.025956  0.028262

# %% [markdown]
# **STEP 4 - Data Splitting and Sequencing**

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
train_data.head()
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# **STEP 5 - Model Building and Training**

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 50, 50)              │          10,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 2)                   │             102 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,902 (120.71 KB)
#  Trainable params: 30,902 (120.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0151 - mean_absolute_error: 0.0906 - val_loss: 0.0109 - val_mean_absolute_error: 0.0830
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 9.3859e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0079 - val_mean_absolute_error: 0.0748
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.8239e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.1945e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0016 - val_mean_absolute_error: 0.0309
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.1137e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0021 - val_mean_absolute_error: 0.0343
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.5735e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0022 - val_mean_absolute_error: 0.0355
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.9977e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0041 - val_mean_absolute_error: 0.0514
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.1766e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0035 - val_mean_absolute_error: 0.0452
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.2279e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0028 - val_mean_absolute_error: 0.0403
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.8781e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0033 - val_mean_absolute_error: 0.0442
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 3.7648e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.5523e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0071 - val_mean_absolute_error: 0.0710
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.7666e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 2.8789e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0031 - val_mean_absolute_error: 0.0426
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.1410e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0052 - val_mean_absolute_error: 0.0589
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 3.2873e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0031 - val_mean_absolute_error: 0.0429
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 2.6589e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.9491e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0039 - val_mean_absolute_error: 0.0489
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3635e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0049 - val_mean_absolute_error: 0.0559
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.0547e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0057 - val_mean_absolute_error: 0.0616
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.6081e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0033 - val_mean_absolute_error: 0.0442
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.5794e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0514
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 2.9087e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0039 - val_mean_absolute_error: 0.0482
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.8775e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 2.7310e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0030 - val_mean_absolute_error: 0.0414
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.3193e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0025 - val_mean_absolute_error: 0.0380
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 2.6910e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0049 - val_mean_absolute_error: 0.0573
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3292e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0027 - val_mean_absolute_error: 0.0397
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 2.8804e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0027 - val_mean_absolute_error: 0.0388
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.7842e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0025 - val_mean_absolute_error: 0.0380
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 2.7745e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0032 - val_mean_absolute_error: 0.0443
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.8183e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0036 - val_mean_absolute_error: 0.0484
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 2.7646e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2105e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0020 - val_mean_absolute_error: 0.0338
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.0909e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0033 - val_mean_absolute_error: 0.0449
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 2.4303e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 2.3156e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 2.2560e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0033 - val_mean_absolute_error: 0.0449
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 2.1948e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 2.1832e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 1.9413e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0402
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 2.1499e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0039 - val_mean_absolute_error: 0.0495
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.0198e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0359
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.0890e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1309e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0023 - val_mean_absolute_error: 0.0368
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.9466e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0034 - val_mean_absolute_error: 0.0469
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.9383e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0037 - val_mean_absolute_error: 0.0486
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.9050e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 2.0037e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0025 - val_mean_absolute_error: 0.0400
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1027e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0017 - val_mean_absolute_error: 0.0311
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7539e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0036 - val_mean_absolute_error: 0.0489
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 2.0814e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7009e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0030 - val_mean_absolute_error: 0.0444
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.4108e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 1.8514e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0038 - val_mean_absolute_error: 0.0499
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.9354e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0031 - val_mean_absolute_error: 0.0453
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.8940e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6142e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0295
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.6149e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.6059e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0394
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.6862e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0406
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.4708e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0023 - val_mean_absolute_error: 0.0363
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5120e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0026 - val_mean_absolute_error: 0.0406
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.7616e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4482e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.5844e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0036 - val_mean_absolute_error: 0.0492
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.5791e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 1.9876e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0029 - val_mean_absolute_error: 0.0436
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7195e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4610e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.7064e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3334e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0018 - val_mean_absolute_error: 0.0330
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.4182e-04 - mean_absolute_error: 0.0086 - val_loss: 8.3206e-04 - val_mean_absolute_error: 0.0211
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3946e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0083 - val_loss: 9.0198e-04 - val_mean_absolute_error: 0.0226
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4647e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.4822e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.4332e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2625e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0030 - val_mean_absolute_error: 0.0432
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.2877e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0031 - val_mean_absolute_error: 0.0462
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 1.3391e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0018 - val_mean_absolute_error: 0.0337
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 1.4371e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0024 - val_mean_absolute_error: 0.0398
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4259e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.3155e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.1256e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1.1423e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.4194e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.3211e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.1391e-04 - mean_absolute_error: 0.0076 - val_loss: 6.7702e-04 - val_mean_absolute_error: 0.0195
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.2764e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.2128e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0021 - val_mean_absolute_error: 0.0378
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 1.0551e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0503e-04 - mean_absolute_error: 0.0076 - val_loss: 8.7157e-04 - val_mean_absolute_error: 0.0222
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.2598e-04 - mean_absolute_error: 0.0079 - val_loss: 9.8108e-04 - val_mean_absolute_error: 0.0230
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.2068e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0605e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 97/100

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# array([[0.3917776 , 0.39872056],
#        [0.39026317, 0.3974687 ],
#        [0.3853837 , 0.39269844],
#        [0.39040238, 0.39692914],
#        [0.39458767, 0.40086514]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1397.3243, 1407.2249],
#        [1394.5166, 1404.9047],
#        [1385.4705, 1396.0637],
#        [1394.7748, 1403.9047],
#        [1402.5339, 1411.1995]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1397.324341      1407.224854
# 2020-05-28  1396.86  1416.73     1394.516602      1404.904663
# 2020-05-29  1416.94  1428.92     1385.470459      1396.063721
# 2020-06-01  1418.39  1431.82     1394.774780      1403.904663
# 2020-06-02  1430.55  1439.22     1402.533936      1411.199463

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# STEP 7 - Upcoming Price Prediction

# %%
# Creating a new DataFrame to append 10 days of empty data
new_data = pd.DataFrame(index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))

# Appending the new_data to df_merge
df_merge = pd.concat([df_merge, new_data])

# Now you can select the specific date range
selected_date_range = df_merge['2021-06-09':'2021-06-28']
print(selected_date_range)
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2337.363525      2387.834961
# 2021-06-10  2494.01  2521.60     2337.119629      2391.128418
# 2021-06-11  2524.92  2513.93     2348.599609      2402.314209
# 2021-06-11      NaN      NaN             NaN              NaN
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN
# 2021-06-17      NaN      NaN             NaN              NaN
# 2021-06-18      NaN      NaN             NaN              NaN
# 2021-06-19      NaN      NaN             NaN              NaN
# 2021-06-20      NaN      NaN             NaN              NaN
# 2021-06-21      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
