# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayykkumar/Forecasting-Trends-with-Powerful-LSTM_Models_Infosys_Internship_Oct2024/blob/main/infosys_milestone_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv('pollution_test_data1.csv')
df
# Out:
#      dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0    -16     4   1027      SE     3.58     0     0        128
# 1    -17     5   1027      SE     7.60     0     0         77
# 2    -16     4   1027      SE     9.39     0     0         65
# 3    -16     1   1028      cv     0.89     0     0         79
# 4    -14     0   1028      NE     1.79     0     0         93
# ..   ...   ...    ...     ...      ...   ...   ...        ...
# 341  -23    -2   1034      NW   231.97     0     0          8
# 342  -22    -3   1034      NW   237.78     0     0         10
# 343  -22    -3   1034      NW   242.70     0     0         10
# 344  -22    -4   1034      NW   246.72     0     0          8
# 345  -21    -3   1034      NW   249.85     0     0         12
#
# [346 rows x 8 columns]

# %%
df.head()
# Out:
#    dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0  -16     4   1027      SE     3.58     0     0        128
# 1  -17     5   1027      SE     7.60     0     0         77
# 2  -16     4   1027      SE     9.39     0     0         65
# 3  -16     1   1028      cv     0.89     0     0         79
# 4  -14     0   1028      NE     1.79     0     0         93

# %%
df.tail()
# Out:
#      dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 341  -23    -2   1034      NW   231.97     0     0          8
# 342  -22    -3   1034      NW   237.78     0     0         10
# 343  -22    -3   1034      NW   242.70     0     0         10
# 344  -22    -4   1034      NW   246.72     0     0          8
# 345  -21    -3   1034      NW   249.85     0     0         12

# %%
df.shape
# Out:
# (346, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dew        346 non-null    int64
#  1   temp       346 non-null    int64
#  2   press      346 non-null    int64
#  3   wnd_dir    346 non-null    object
#  4   wnd_spd    346 non-null    float64
#  5   snow       346 non-null    int64
#  6   rain       346 non-null    int64
#  7   pollution  346 non-null    int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 21.8+ KB

# %%
#finding missing value
df.isnull().sum()
# Out:
# dew          0
# temp         0
# press        0
# wnd_dir      0
# wnd_spd      0
# snow         0
# rain         0
# pollution    0
# dtype: int64

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#            count         mean         std      min      25%       50%  \
# dew        346.0   -13.878613    4.029925   -27.00   -16.00   -14.000
# temp       346.0    -0.653179    4.548732    -9.00    -4.00    -1.500
# press      346.0  1026.083815    5.996272  1011.00  1022.00  1027.000
# wnd_spd    346.0    62.473815  107.500012     0.45     2.67     7.825
# snow       346.0     0.000000    0.000000     0.00     0.00     0.000
# rain       346.0     0.000000    0.000000     0.00     0.00     0.000
# pollution  346.0    96.398844   98.298524     0.00    14.00    63.500
#
#                  75%      max
# dew         -11.0000    -6.00
# temp          2.0000    11.00
# press      1031.0000  1035.00
# wnd_spd      58.7825   441.18
# snow          0.0000     0.00
# rain          0.0000     0.00
# pollution   157.5000   444.00

# %%
df.describe(include='object')
# Out:
#        wnd_dir
# count      346
# unique       4
# top         NW
# freq       206

# %%
import pandas as pd

df=pd.read_csv('pollution_test_data1.csv',usecols=[0,1,2])
df.head()
# Out:
#    dew  temp  press
# 0  -16     4   1027
# 1  -17     5   1027
# 2  -16     4   1027
# 3  -16     1   1028
# 4  -14     0   1028

# %%
from sklearn.preprocessing import MinMaxScaler
Scaling=MinMaxScaler(

)
Scaling.fit_transform(df[['temp','press']])
# Out:
# array([[0.65      , 0.66666667],
#        [0.7       , 0.66666667],
#        [0.65      , 0.66666667],
#        [0.5       , 0.70833333],
#        [0.45      , 0.70833333],
#        [0.35      , 0.75      ],
#        [0.3       , 0.75      ],
#        [0.25      , 0.79166667],
#        [0.3       , 0.79166667],
#        [0.15      , 0.79166667],
#        [0.15      , 0.79166667],
#        [0.1       , 0.79166667],
#        [0.1       , 0.79166667],
#        [0.        , 0.83333333],
#        [0.05      , 0.79166667],
#        [0.15      , 0.83333333],
#        [0.1       , 0.83333333],
#        [0.        , 0.83333333],
#        [0.1       , 0.83333333],
#        [0.25      , 0.83333333],
#        [0.35      , 0.83333333],
#        [0.45      , 0.83333333],
#        [0.5       , 0.75      ],
#        [0.55      , 0.70833333],
#        [0.55      , 0.66666667],
#        [0.55      , 0.625     ],
#        [0.5       , 0.625     ],
#        [0.4       , 0.625     ],
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('pollution_test_data1.csv')

df
# Out:
#      dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0    -16     4   1027      SE     3.58     0     0        128
# 1    -17     5   1027      SE     7.60     0     0         77
# 2    -16     4   1027      SE     9.39     0     0         65
# 3    -16     1   1028      cv     0.89     0     0         79
# 4    -14     0   1028      NE     1.79     0     0         93
# ..   ...   ...    ...     ...      ...   ...   ...        ...
# 341  -23    -2   1034      NW   231.97     0     0          8
# 342  -22    -3   1034      NW   237.78     0     0         10
# 343  -22    -3   1034      NW   242.70     0     0         10
# 344  -22    -4   1034      NW   246.72     0     0          8
# 345  -21    -3   1034      NW   249.85     0     0         12
#
# [346 rows x 8 columns]
